# %%
import conin
from conin.common import load_model, save_model
from conin.bayesian_network.tests.examples import cancer1_BN_pgmpy
from pgmpy.readwrite import UAI, BIF

# %% [markdown]
# Test Bayesian Instance

# %%
bn_pgm = cancer1_BN_pgmpy()
UAI.UAIWriter(bn_pgm).write_uai(filename='bn_cancer1.uai')
BIF.BIFWriter(bn_pgm).write_bif(filename='bn_cancer1.bif')

# %%
bn_conin = load_model('bn_cancer1.uai')
save_model(bn_conin, 'bn_cancer1_test.uai')

# %%
bn_conin_2 = load_model('bn_cancer1_test.uai')

# %%
print(bn_conin.cpds)

# %%
print(bn_conin_2.cpds)

# %% [markdown]
# Test Markovian Instance

# %%
mn_pgm = bn_pgm.to_markov_model()
UAI.UAIWriter(mn_pgm).write_uai(filename='mn_cancer1.uai')

# %%
mn_conin = load_model('mn_cancer1.uai')
save_model(mn_conin, 'mn_cancer1_test.uai')

# %%
mn_conin_2 = load_model('mn_cancer1_test.uai')

# %%
print(mn_conin.factors)

# %%
print(mn_conin_2.factors)
